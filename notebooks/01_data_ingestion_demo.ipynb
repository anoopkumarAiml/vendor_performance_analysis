# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time

engine = create_engine("mysql+pymysql://root:@Vasvikas83@loclhost/vendor_db")

logging.basicConfig(
    filename = "../logs/vendor_db.log",
    level = logging.DEBUG,
    format= "%(asctime)s - %(levelname)s - %(message)s",
    filemode= "a"


)

def ingest_db(df, table_name, engine):
    """This function will ingest the dataframe into database table"""
    df.to_sql(table_name, con = engine, if_exists = "replace", index = False)


def load_raw_data():
    start = time.time()
    for file in os.listdir("data"):
        if ".csv" in file:
            df = pd.read_csv("data/"+file)
            logging.info(f"Ingesting (file) in db")
            ingest_db(df, file[:-4] , engine)
    end = time.time()
    total_time = (end - start)/60
    logging.info("----------Ingestion Complete----------")
    
    logging.info("Total TimeTaken: {total_time} minutes")

if __name__ == "__main__":
    load_raw_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 37
#      34     logging.info("Total TimeTaken: {total_time} minutes")
#      36 if __name__ == "__main__":
# ---> 37     load_raw_data()
#
# Cell In[2], line 25, in load_raw_data()
#      23 def load_raw_data():
#      24     start = time.time()
# ---> 25     for file in os.listdir("data"):
#      26         if ".csv" in file:
#      27             df = pd.read_csv("data/"+file)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data'

# %%
def ingest_db(df, table_name, engine):
    """This function will ingest the dataframe into database table"""
    df.to_sql(table_name, con = engine, if_exists = "replace", index = False)

# %%
def load_raw_data():
    start = time.time()
    for file in os.listdir("../data"):
        if ".csv" in file:
            df = pd.read_csv("../data/"+file)
            logging.info(f"Ingesting (file) in db")
            ingest_db(df, file[:-4] , engine)
    end = time.time()
    total_time = (end - start)/60
    logging.info("----------Ingestion Complete----------")
    
    logging.info("Total TimeTaken: {total_time} minutes")

if __name__ == "__main__":
    load_raw_data()

# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:%40Vasvikas83@localhost/vendor_db")

# %%
for file in os.listdir("../data"):
    if ".csv" in file:
        df = pd.read_csv("../data/"+ file)
        print(df.shape)
# Out:
# (206529, 9)
# (224489, 9)
# (2372474, 16)
# (12261, 9)
# (12825363, 14)
# (5543, 10)

# %%
def ingest_db(df, table_name, engine):
    df.to_sql(table_name, con = engine, if_exists= "replace", index= False, method= "multi", chunksize = 50000)
